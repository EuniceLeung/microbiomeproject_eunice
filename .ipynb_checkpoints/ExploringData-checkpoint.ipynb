# %%
import numpy as np
import pandas as pd
import os

import matplotlib.pyplot as plt
import seaborn as sns

# %%
os.listdir()
# Out:
# ['ExploringData.ipynb',
#  '.DS_Store',
#  'readme.md',
#  '.gitignore',
#  'test.txt',
#  '.ipynb_checkpoints',
#  '.git',
#  'Data']

# %%
basedir = os.getcwd()
datadir = basedir + "/Data"

# %%
os.listdir(datadir)
# Out:
# ['otu_annotation.csv',
#  '.DS_Store',
#  'archive',
#  'microbiome_data.csv',
#  'sample_desc_deid.csv']

# %%
data = pd.read_csv(datadir + '/microbiome_data.csv', index_col = 0)
OTUref = pd.read_csv(datadir + '/otu_annotation.csv', index_col = 0)
sample_desc = pd.read_csv(datadir + '/sample_desc_deid.csv', index_col = 0)

# %%
data
# Out:
#           1001360178  1000106028  1000160068  1001406208  1000606198  \
# OTUId
# OTU_25          1152         306         459         586        1468
# OTU_38           367        1091         727         328          58
# OTU_233            0           0           0         959           0
# OTU_962           55          20          17          32          71
# OTU_168            0           0           0           0           0
# ...              ...         ...         ...         ...         ...
# OTU_1764           0           0           0           0           0
# OTU_1854           0           0           0           0           0
# OTU_1803           0           0           0           0           0
# OTU_1593           0           0           0           0           0
# OTU_1382           0           0           0           0           0
#
#           1000105048  1000603178  1000601248  1000860248  1000101018  ...  \
# ...

# %%
OTUref
# Out:
#            Kingdom          Phylum                Class            Order  \
# OTUId
# OTU_25    Bacteria  Actinobacteria       Actinobacteria  Actinomycetales
# OTU_38    Bacteria      Firmicutes              Bacilli       Bacillales
# OTU_233   Bacteria  Actinobacteria       Actinobacteria  Actinomycetales
# OTU_962   Bacteria  Actinobacteria       Actinobacteria  Actinomycetales
# OTU_168   Bacteria      Firmicutes           Clostridia    Clostridiales
# ...            ...             ...                  ...              ...
# OTU_1764  Bacteria  Proteobacteria  Deltaproteobacteria     Myxococcales
# OTU_1854  Bacteria   Bacteroidetes          Bacteroidia    Bacteroidales
# OTU_1803  Bacteria      Firmicutes           Clostridia    Clostridiales
# OTU_1593  Bacteria             NaN                  NaN              NaN
# OTU_1382  Bacteria      Firmicutes           Clostridia    Clostridiales
#
#                         Family              Genus      Species
# OTUId
# ...

# %%
sample_desc
# Out:
#                   BarcodeSequence   LinkerPrimerSequence      BodySite  \
# #SampleID
# 1000201108           AACGCACGCTAG  GCACTCCTACGGGAGGCAGCA  Vaginal_Swab
# 1000501278           AACTCGTCGATG  GCACTCCTACGGGAGGCAGCA  Vaginal_Swab
# 1000101018           AACTGTGCGTAC  GCACTCCTACGGGAGGCAGCA  Vaginal_Swab
# 1000101028           AAGAGATGTCGA  GCACTCCTACGGGAGGCAGCA  Vaginal_Swab
# 1000201118           AAGCTGCAGTCG  GCACTCCTACGGGAGGCAGCA  Vaginal_Swab
# ...                           ...                    ...           ...
# 1010104488.rs        GTCTGACAGTTG  GCACTCCTACGGGAGGCAGCA     Tooth_Gum
# 1002402218.ca2.rs    GTCTGGATAGCG  GCACTCCTACGGGAGGCAGCA         Stool
# 1002302248.bn1.rs    GTCTTCGTCGCT  GCACTCCTACGGGAGGCAGCA         Stool
# 1002102208.ak2.rs    GTGACCTGATGT  GCACTCCTACGGGAGGCAGCA         Stool
# NTC52.rs             GTGTCTACATTG  GCACTCCTACGGGAGGCAGCA           NTC
#
#                   SubjectID  GestDayColl  GestWeekColl  TrimColl  \
# #SampleID
# ...

# %%
sample_desc.columns
# Out:
# Index(['BarcodeSequence', 'LinkerPrimerSequence', 'BodySite', 'SubjectID',
#        'GestDayColl', 'GestWeekColl', 'TrimColl', 'intra_ut_fetal_demise',
#        'History_of_preterm_delivery', 'Withdrew', 'Gdwithdrawal',
#        'GWwithdrawal', 'Delivered', 'GestDayDel', 'GestWeekdel',
#        'Labor_Initiation', 'Indication', 'PPROM', 'Chorioamnionitis',
#        'Endometritis', 'Hypertensive Disorder', 'Preeclampsia',
#        'Birthweight_kg', 'Length_at_birth', 'Number_of_babies', 'Race',
#        'Ethnicity', 'ReversePrimer', 'Saliva_volume_uL',
#        'Note_any_concerns_regarding_the_specimen', 'Run_No',
#        'Number_within_run', 'Bead_Beating_Time', 'Description'],
#       dtype='object')

# %%
sample_desc['Race'].value_counts()
# Out:
# White                    2694
# Other (Specify below)     557
# American Indian           194
# Asian-Chinese             151
# Pacific Islander          139
# Indian                    122
# Black                     120
# Asian-Unspecified         120
# Asian-Japanese             40
# Name: Race, dtype: int64

# %%
sample_desc['Ethnicity'].value_counts()
# Out:
# Non-hispanic    2713
# Hispanic        1403
# 0                 21
# Name: Ethnicity, dtype: int64

# %%
sample_desc['BodySite'].value_counts()
# Out:
# Vaginal_Swab          1072
# Saliva                1033
# Tooth_Gum              976
# Stool                  887
# mock                   213
# NTC                     52
# Back_of_ear_L           51
# Urine                   34
# Back_of_ear_R           34
# Elbow_crease_R          29
# Cord Blood (Serum)      21
# Name: BodySite, dtype: int64

# %%
sample_desc['SubjectID'].value_counts()
# Out:
# mock     213
# 10101    206
# 10023    166
# 10039    160
# 10022    156
# 10028    155
# 10046    153
# 10032    152
# 10034    151
# 10006    146
# 10044    139
# 10045    138
# 10018    137
# 10043    134
# 10047    130
# 19005    128
# 10040    122
# 10014    120
# 10021    117
# 10031    116
# 10001    115
# 10024    110
# 19004    108
# 10036     99
# 10025     98
# 10013     90
# 10008     89
# 10055     85
# 10020     60
# 10003     53
# NTC       52
# 10029     52
# 19007     45
# 10009     43
# 10017     42
# 19006     41
# 10005     40
# 10002     40
# 19009     38
# 10004     27
# 10007     26
# 19010     21
# 10016     19
# 10027     18
# 10012     16
# 19008     14
# 10015      7
# 10010      6
# 10011      4
# 19003      4
# 10035      1
# Name: SubjectID, dtype: int64

# %%
sns.countplot(sample_desc['BodySite'])
plt.xticks(rotation = 45, ha = 'right')
plt.savefig(basedir + '/Figures/bodysite.png', bbox_inches='tight')
# Out:
# /Users/euniceleung/opt/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
