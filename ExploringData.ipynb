# %%
import numpy as np
import pandas as pd
import os

import matplotlib.pyplot as plt

# %%
os.listdir()
# Out:
# ['ExploringData.ipynb',
#  '.DS_Store',
#  'readme.md',
#  '.gitignore',
#  'test.txt',
#  '.ipynb_checkpoints',
#  '.git',
#  'Data']

# %%
basedir = os.getcwd()
datadir = basedir + "/Data"

# %%
os.listdir(datadir)
# Out:
# ['patients_assay.csv', '.DS_Store', 'OTUref.csv', 'data.csv']

# %%
data = pd.read_csv(datadir + '/data.csv', index_col = 0)
OTUref = pd.read_csv(datadir + '/OTUref.csv', index_col = 0)
pat_assay = pd.read_csv(datadir + '/patients_assay.csv', index_col = 0)

# %%
data
# Out:
#           OTU_25  OTU_38  OTU_233  OTU_962  OTU_168  OTU_1330  OTU_3  OTU_153  \
# BS742747       0       0        0        0        2         0      0        6
# BS742748       1       0        0        0        0         0      0        0
# BS742758       0       0        0        0        0         0      0        0
# BS742759       0      15        0        0       14         0      0        0
# BS742760       0       0        0        0        9         0      0        0
# ...          ...     ...      ...      ...      ...       ...    ...      ...
# BS746735       0       3        0        0        1         6      0        0
# BS746749       0       0        0        0        1        15      0        0
# BS746817       0       0        0        0        0         0      0        0
# BS746821       0       0        0        0        0         0      0        0
# BS746595       0     467        0        0        0         0     12        0
#
# ...

# %%
OTUref
# Out:
#                     k                  p                       c  \
# OTUId
# OTU_1     k__Bacteria      p__Firmicutes              c__Bacilli
# OTU_10    k__Bacteria      p__Firmicutes           c__Clostridia
# OTU_100   k__Bacteria   p__Bacteroidetes       c__Flavobacteriia
# OTU_1000  k__Bacteria  p__Proteobacteria  c__Gammaproteobacteria
# OTU_1001  k__Bacteria      p__Firmicutes           c__Clostridia
# ...               ...                ...                     ...
# OTU_995   k__Bacteria    p__Fusobacteria        c__Fusobacteriia
# OTU_996   k__Bacteria      p__Firmicutes           c__Clostridia
# OTU_997   k__Bacteria   p__Bacteroidetes          c__Bacteroidia
# OTU_998   k__Bacteria    p__Spirochaetes         c__Spirochaetes
# OTU_999   k__Bacteria  p__Actinobacteria       c__Actinobacteria
#
#                             o                      f                   g  \
# OTUId
# OTU_1      o__Lactobacillales    f__Streptococcaceae    g__Streptococcus
# ...

# %%
pat_assay[['Subject Accession','Race']].drop_duplicates()
# Out:
#     Subject Accession                              Race
# 0           SUB142505                             White
# 106         SUB142506                             White
# 146         SUB142507  American Indian or Alaska Native
# 198         SUB142508                             White
# 225         SUB142509                             Asian
# 265         SUB142510                             White
# 404         SUB142511                             White
# 430         SUB142512                             White
# 509         SUB142513                             White
# 551         SUB142514         Black or African American
# 557         SUB142515  American Indian or Alaska Native
# 561         SUB142516         Black or African American
# 577         SUB142517                             White
# 652         SUB142518                             Asian
# 688         SUB142522  American Indian or Alaska Native
# 740         SUB142540                             White
